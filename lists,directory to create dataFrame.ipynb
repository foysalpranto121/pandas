# %%
#import Library
import pandas as pd

# %%
#Empty 
df= pd.DataFrame()
print(df)
df.info()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city=["Dhaka","Sylhet","Mym"]

# %%
city
# Out:
# ['Dhaka', 'Sylhet', 'Mym']

# %%
import pandas as pd

# %%
df= pd.DataFrame(city)
df
# Out:
#         0
# 0   Dhaka
# 1  Sylhet
# 2     Mym

# %%
type(city)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
row,col=df.shape
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
df.shape
# Out:
# (3, 1)

# %%
df= pd.DataFrame(city,columns=['City of BD'],index=['c1','c2','c3'])
df
# Out:
#    City of BD
# c1      Dhaka
# c2     Sylhet
# c3        Mym

# %%
city2=['borisal','ctg','dhaka']
df2=pd.DataFrame(zip(city,city2),columns=['city1','city2'])

# %%
df2
# Out:
#     city1    city2
# 0   Dhaka  borisal
# 1  Sylhet      ctg
# 2     Mym    dhaka

# %%
df2.shape
# Out:
# (3, 2)

# %%
city3=[['rajastan','Delhi'],['mrw','ctg']]

# %%
df3=pd.DataFrame(city3,columns=['State','City'])

# %%
df3
# Out:
#       State   City
# 0  rajastan  Delhi
# 1       mrw    ctg

# %%
city
# Out:
# ['Dhaka', 'Sylhet', 'Mym']

# %%
city2
# Out:
# ['borisal', 'ctg', 'dhaka']

# %%
dict1={
'city1':city,
'city2':city2


}

# %%
dict1
# Out:
# {'city1': ['Dhaka', 'Sylhet', 'Mym'], 'city2': ['borisal', 'ctg', 'dhaka']}

# %%
df4=pd.DataFrame(dict1)

# %%
df4
# Out:
#     city1    city2
# 0   Dhaka  borisal
# 1  Sylhet      ctg
# 2     Mym    dhaka

# %%
type(dict1)
# Out:
# dict

# %%
import pandas as pd

# %%
#importing excel file
df5=pd.read_excel("C:/Users/ASUS/Downloads/Software Architecture .xlsx")

# %%
df5
# Out:
#       Team                     Name                ID  \
# 0    Team 1      Sanim Yousuf Fahim  0242310005341092
# 1       NaN         Md. Eusha Hasan  0242310005341058
# 2       NaN     Nayeef Sarker Nafi   0242310005341222
# 3       NaN  Syeda Aysha Akter Asha  0242310005341293
# 4       NaN                     NaN               NaN
# ..      ...                     ...               ...
# 59      NaN                     NaN               NaN
# 60  Team 11        Mushfiqur Rahman  0242310005341405
# 61      NaN              Md.Faysal   0242310005341367
# 62      NaN         Shakib Al Hasan  0242310005341218
# 63      NaN            Mehedi Hasan  0242310005341436
#
#                                           Topic
# 0   4+1 View model architecture + Microservices
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df5 = df5.dropna(how='all')  # Drop rows where all cells are NaN

# %%
df5
# Out:
#       Team                      Name                  ID  \
# 0    Team 1       Sanim Yousuf Fahim    0242310005341092
# 1       NaN          Md. Eusha Hasan    0242310005341058
# 2       NaN      Nayeef Sarker Nafi     0242310005341222
# 3       NaN   Syeda Aysha Akter Asha    0242310005341293
# 6    Team 2     Foysal Ahmed Pranto           232-35-671
# 7       NaN         MD.Farhan Tanvir          232-35-674
# 8       NaN   Tonmoy Krishna Debnath          232-35-578
# 9       NaN               Mahin Alam          232-35-672
# 12  Team 3       Momtaz Farah Ahmed           232-35-742
# 13      NaN     Foysal Mahmud Purno     0242310005341115
# 14      NaN       Imran Hasan Murad     0242310005341133
# 15      NaN           Mahbuba Islam     0242310005341029
# 18   Team 4             Mahima Mobin   02423100053411319
# 19      NaN      Zahed Ibna Morshed     0242310005341377
# 20      NaN           Hasibur Rahman    0242310005341380
# ...

# %%
import pandas as pd

# Show all rows
pd.set_option('display.max_rows', None)

# Show all columns
pd.set_option('display.max_columns', None)

# Optional: Show full content in each cell
pd.set_option('display.max_colwidth', None)

# Now load and view the Excel file
df = pd.read_excel(r"C:\Users\ASUS\Downloads\Software Architecture .xlsx")
print(df)
# Out:
#       Team                      Name                  ID  \
# 0    Team 1       Sanim Yousuf Fahim    0242310005341092
# 1       NaN          Md. Eusha Hasan    0242310005341058
# 2       NaN      Nayeef Sarker Nafi     0242310005341222
# 3       NaN   Syeda Aysha Akter Asha    0242310005341293
# 4       NaN                      NaN                 NaN
# 5       NaN                      NaN                 NaN
# 6    Team 2     Foysal Ahmed Pranto           232-35-671
# 7       NaN         MD.Farhan Tanvir          232-35-674
# 8       NaN   Tonmoy Krishna Debnath          232-35-578
# 9       NaN               Mahin Alam          232-35-672
# 10      NaN                      NaN                 NaN
# 11      NaN                      NaN                 NaN
# 12  Team 3       Momtaz Farah Ahmed           232-35-742
# 13      NaN     Foysal Mahmud Purno     0242310005341115
# 14      NaN       Imran Hasan Murad     0242310005341133
# ...

# %%
df.head(20)
# Out:
#       Team                     Name                 ID  \
# 0    Team 1      Sanim Yousuf Fahim   0242310005341092
# 1       NaN         Md. Eusha Hasan   0242310005341058
# 2       NaN     Nayeef Sarker Nafi    0242310005341222
# 3       NaN  Syeda Aysha Akter Asha   0242310005341293
# 4       NaN                     NaN                NaN
# 5       NaN                     NaN                NaN
# 6    Team 2    Foysal Ahmed Pranto          232-35-671
# 7       NaN        MD.Farhan Tanvir         232-35-674
# 8       NaN  Tonmoy Krishna Debnath         232-35-578
# 9       NaN              Mahin Alam         232-35-672
# 10      NaN                     NaN                NaN
# 11      NaN                     NaN                NaN
# 12  Team 3      Momtaz Farah Ahmed          232-35-742
# 13      NaN    Foysal Mahmud Purno    0242310005341115
# 14      NaN      Imran Hasan Murad    0242310005341133
# 15      NaN          Mahbuba Islam    0242310005341029
# ...

# %%
df.tail()
# Out:
#       Team               Name                ID Topic
# 59      NaN               NaN               NaN   NaN
# 60  Team 11  Mushfiqur Rahman  0242310005341405   NaN
# 61      NaN        Md.Faysal   0242310005341367   NaN
# 62      NaN   Shakib Al Hasan  0242310005341218   NaN
# 63      NaN      Mehedi Hasan  0242310005341436   NaN

# %%
df.shape
# Out:
# (64, 4)

# %%
rows,cols=df.shape

# %%
rows
# Out:
# 64

# %%
cols
# Out:
# 4

# %%
df.values
# Out:
# array([['Team 1', 'Sanim Yousuf Fahim', '0242310005341092',
#         '4+1 View model architecture + Microservices'],
#        [nan, 'Md. Eusha Hasan', '0242310005341058', nan],
#        [nan, 'Nayeef Sarker Nafi ', '0242310005341222', nan],
#        [nan, 'Syeda Aysha Akter Asha', '0242310005341293', nan],
#        [nan, nan, nan, nan],
#        [nan, nan, nan, nan],
#        ['Team 2', 'Foysal Ahmed Pranto ', '232-35-671',
#         'Layered Architecture'],
#        [nan, 'MD.Farhan Tanvir', '232-35-674', nan],
#        [nan, 'Tonmoy Krishna Debnath', '232-35-578', nan],
#        [nan, 'Mahin Alam', '232-35-672', nan],
#        [nan, nan, nan, nan],
#        [nan, nan, nan, nan],
#        ['Team 3 ', 'Momtaz Farah Ahmed ', '232-35-742', nan],
#        [nan, 'Foysal Mahmud Purno ', '0242310005341115', nan],
#        [nan, 'Imran Hasan Murad ', '0242310005341133', nan],
#        [nan, 'Mahbuba Islam ', '0242310005341029', nan],
#        [nan, nan, nan, nan],
# ...

# %%
df.columns
# Out:
# Index(['Team ', 'Name', 'ID', 'Topic'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=64, step=1)

# %%
df.Topic
# Out:
# 0     4+1 View model architecture + Microservices
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                            Layered Architecture
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# ...

# %%
df.sort_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.sort_values
#
# NameError: name 'df' is not defined

# %%
# Statical analysis
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Statical analysis
# ----> 2 df.describe()
#
# NameError: name 'df' is not defined

# %%
##correlation

df.corr
# Out:
# <bound method DataFrame.corr of       Team                      Name                  ID  \
# 0    Team 1       Sanim Yousuf Fahim    0242310005341092
# 1       NaN          Md. Eusha Hasan    0242310005341058
# 2       NaN      Nayeef Sarker Nafi     0242310005341222
# 3       NaN   Syeda Aysha Akter Asha    0242310005341293
# 4       NaN                      NaN                 NaN
# 5       NaN                      NaN                 NaN
# 6    Team 2     Foysal Ahmed Pranto           232-35-671
# 7       NaN         MD.Farhan Tanvir          232-35-674
# 8       NaN   Tonmoy Krishna Debnath          232-35-578
# 9       NaN               Mahin Alam          232-35-672
# 10      NaN                      NaN                 NaN
# 11      NaN                      NaN                 NaN
# 12  Team 3       Momtaz Farah Ahmed           232-35-742
# 13      NaN     Foysal Mahmud Purno     0242310005341115
# 14      NaN       Imran Hasan Murad     0242310005341133
# ...

# %%
import seaborn as sns
sns .heatmap (df.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 import seaborn as sns
# ----> 2 sns .heatmap (df.corr(),annot=True)
#
# File e:\Pandas for ML\.venv\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File e:\Pandas for ML\.venv\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 3.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/8.1 MB 3.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/8.1 MB 3.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/8.1 MB 3.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.1 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.1 MB 2.0 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.1 MB 2.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.1 MB 1.9 MB/s eta 0:00:02
# ...
